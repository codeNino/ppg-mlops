# %%
from preprocessor import (create_feature_target_df)

# %%
feature_target_df = create_feature_target_df("./PPG_Raw_Dataset/RawData/",
               "./PPG_Raw_Dataset/Labels/")
# Out:
# dataframe
# ppg signal read
# features extracted from ppg signal
# dataframe
# ppg signal read
# features extracted from ppg signal
# dataframe
# ppg signal read
# features extracted from ppg signal
# dataframe
# ppg signal read
# features extracted from ppg signal
# dataframe
# ppg signal read
# features extracted from ppg signal
# dataframe
# ppg signal read
# features extracted from ppg signal
# dataframe
# ppg signal read
# features extracted from ppg signal
# dataframe
# ppg signal read
# features extracted from ppg signal
# dataframe
# ppg signal read
# features extracted from ppg signal
# dataframe
# ppg signal read
# features extracted from ppg signal
# dataframe
# ppg signal read
# features extracted from ppg signal
# dataframe
# ppg signal read
# features extracted from ppg signal
# dataframe
# ppg signal read
# features extracted from ppg signal
# dataframe
# ppg signal read
# features extracted from ppg signal
# dataframe
# ppg signal read
# ...

# %%
feature_target_df.head(10)
# Out:
#    mean_ppg   std_ppg  skew_ppg  kurtosis_ppg     mean_hr     std_hr  \
# 0 -0.001149  3.280170  1.368408      0.981262  149.291419  27.868596
# 1  0.064923  1.884787  0.024405      5.243710  115.918286   7.393483
# 2  0.067022  1.996274  0.843849      2.914905  124.811148  40.180866
# 3  0.069762  3.381581  1.097108      0.531415  124.505408  40.825147
# 4 -0.059025  3.523804  1.264912      0.714445  153.491963  32.982445
# 5  0.097667  3.966573  1.007508      1.815027  146.973122  35.559795
# 6  0.125971  1.730022  1.616525     10.204135  149.592021  35.226312
# 7  0.028949  2.485033  1.439999      1.134794  144.708887  43.931302
# 8 -0.000937  3.377512  0.888967     -0.116141  148.622553  29.771162
# 9  0.006684  2.773817  1.217304      0.547906  161.768122  24.140779
#
#    lf_power  hf_power  lf_hf_ratio  pulse_rate  age  gender  height  weight  \
# 0       0.0  0.000105          0.0  148.979405   50    Male     175      96
# ...

# %%
feature_target_df.to_csv("ppg_sample_dataset.csv", index=False)
